# %%
import sys
import numpy as np
import os
from os.path import abspath

import matplotlib.pyplot as plt
# %matplotlib inline
import subtle.subtle_io as suio

# import subtle.subtle_preprocess as sup
import subtle.subtle_plot as suplot
import nibabel as nib
import nipype
from nipype.interfaces import fsl
import nipype.interfaces.io

from niwidgets import NiftiWidget
# NiftiWidget(_x0).nifti_plotter()

from IPython.display import Image
print(fsl.Info().version())
# Out:
# /home/jtamir/miniconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 6.0.0

# %%
working_dir = '/raid/jon/data_full_stanford/data/Patient_0545'

# %%
nib_files = []
for filename in os.listdir(working_dir):
    if ".nii" in filename.lower():
        nib_files.append(os.path.join(working_dir,filename))
order = np.argsort([int(os.path.basename(l).split('_')[0]) for l in nib_files])
nib_files = list(np.array(nib_files)[order])
print(nib_files)
# Out:
# ['/raid/jon/data_full_stanford/data/Patient_0545/7_ax_bravo_pre.nii.gz', '/raid/jon/data_full_stanford/data/Patient_0545/10_ax_bravo_c_pre_load_10.nii.gz', '/raid/jon/data_full_stanford/data/Patient_0545/14_ax_bravoc.nii.gz']

# %%
## coregistration
cost = 'corratio'
dof = 6
searchr_x = [-20, 20]
searchr_y = [-20, 20]
searchr_z = [-20, 20]
bins = 256
interp = 'trilinear'

coreg_low_node = nipype.Node(fsl.FLIRT(cost=cost, dof=dof, interp=interp, bins=bins, searchr_x=searchr_x, searchr_y=searchr_y, searchr_z=searchr_z),
                             name='coreg_low')
coreg_full_node = nipype.Node(fsl.FLIRT(cost=cost, dof=dof, interp=interp, bins=bins, searchr_x=searchr_x, searchr_y=searchr_y, searchr_z=searchr_z),
                             name='coreg_full')

# %%
from nipype.interfaces.base import BaseInterface, \
    BaseInterfaceInputSpec, traits, File, TraitedSpec
from nipype.utils.filemanip import split_filename

import nibabel as nb
import numpy as np
import os

class SimpleThresholdInputSpec(BaseInterfaceInputSpec):
    volume = File(exists=True, desc='volume to be thresholded', mandatory=True)
    threshold = traits.Float(desc='everything below this value will be set to zero',
                             mandatory=True)


class SimpleThresholdOutputSpec(TraitedSpec):
    thresholded_volume = File(exists=True, desc="thresholded volume")


class SimpleThreshold(BaseInterface):
    input_spec = SimpleThresholdInputSpec
    output_spec = SimpleThresholdOutputSpec

    def _run_interface(self, runtime):
        fname = self.inputs.volume
        img = nb.load(fname)
        data = np.array(img.get_data())

        active_map = data > self.inputs.threshold

        thresholded_map = np.zeros(data.shape)
        thresholded_map[active_map] = data[active_map]

        new_img = nb.Nifti1Image(thresholded_map, img.affine, img.header)
        _, base, _ = split_filename(fname)
        nb.save(new_img, base + '_thresholded.nii.gz')

        return runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        fname = self.inputs.volume
        _, base, _ = split_filename(fname)
        outputs["thresholded_volume"] = os.path.abspath(base + '_thresholded.nii.gz')
        return outputs

# %%
from nipype.interfaces.base import BaseInterface, \
    BaseInterfaceInputSpec, traits, File, TraitedSpec
from nipype.utils.filemanip import split_filename

import nibabel as nb
import numpy as np
import os

class MaskCombineInputSpec(BaseInterfaceInputSpec):
    in0 = File(exists=True, desc='input 0', mandatory=True)
    in1 = File(exists=True, desc='input 1', mandatory=True)
    in2 = File(exists=True, desc='input 2', mandatory=True)



class MaskCombineOutputSpec(TraitedSpec):
    out = File(exists=True, desc="mask")


class MaskCombine(BaseInterface):
    input_spec = MaskCombineInputSpec
    output_spec = MaskCombineOutputSpec

    def _run_interface(self, runtime):
        f0 = self.inputs.in0
        f1 = self.inputs.in1
        f2 = self.inputs.in2
        
        x0 = nb.load(f0)
        x1 = nb.load(f1)
        x2 = nb.load(f2)
        
        mask = ((x0.get_fdata()>0) & (x1.get_fdata()>0) & (x2.get_fdata()>0))

        out = nb.Nifti1Image(mask, x0.affine, x0.header)
        _, base, _ = split_filename(f0)
        nb.save(out, base + '_combined_mask.nii.gz')

        return runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        fname = self.inputs.in0
        _, base, _ = split_filename(fname)
        outputs["out"] = os.path.abspath(base + '_combined_mask.nii.gz')
        return outputs

# %%
from nipype.interfaces.base import BaseInterface, \
    BaseInterfaceInputSpec, traits, File, TraitedSpec
from nipype.utils.filemanip import split_filename

import nibabel as nb
import numpy as np
import os

class ApplyMaskInputSpec(BaseInterfaceInputSpec):
    input_file = File(exists=True, desc='input', mandatory=True)
    mask = File(exists=True, desc='mask', mandatory=True)



class ApplyMaskOutputSpec(TraitedSpec):
    out = File(exists=True, desc="masked image")


class ApplyMask(BaseInterface):
    input_spec = ApplyMaskInputSpec
    output_spec = ApplyMaskOutputSpec

    def _run_interface(self, runtime):
        f0 = self.inputs.input_file
        fm = self.inputs.mask
        
        x0 = nb.load(f0)
        xm = nb.load(fm)
        
        x_out = x0.get_fdata() * xm.get_fdata()
        
        out = nb.Nifti1Image(x_out, x0.affine, x0.header)
        _, base, _ = split_filename(f0)
        nb.save(out, base + '_masked.nii.gz')

        return runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        fname = self.inputs.input_file
        _, base, _ = split_filename(fname)
        outputs["out"] = os.path.abspath(base + '_masked.nii.gz')
        return outputs

# %%
mask_node = nipype.Node(MaskCombine(), name='mask_combine')
masked_zero_node = nipype.Node(ApplyMask(), name='masked_zero')
masked_low_node = nipype.Node(ApplyMask(), name='masked_low')
masked_full_node = nipype.Node(ApplyMask(), name='masked_full')

# %%
wf = nipype.Workflow(name='registration_no_bet', base_dir=working_dir)
wf.connect([
    (coreg_full_node, mask_node, [('out_file', 'in0')]), 
    (coreg_low_node, mask_node, [('out_file', 'in1')]), 
    (mask_node, masked_zero_node, [('out', 'mask')]), 
    (mask_node, masked_low_node, [('out', 'mask')]), 
    (mask_node, masked_full_node, [('out', 'mask')]), 
    (coreg_low_node, masked_low_node, [('out_file', 'input_file')]), 
    (coreg_full_node, masked_full_node, [('out_file', 'input_file')]), 

           ])

# wf.write_graph('workflow_graph.dot')
# Image(filename='{working_dir}/registration/workflow_graph.png'.format(working_dir=working_dir))

wf.write_graph(graph2use='flat')
Image(filename='{working_dir}/registration_no_bet/graph_detailed.png'.format(working_dir=working_dir))
# Out:
# 190221-21:29:36,849 nipype.workflow INFO:
# 	 Generated workflow graph: /raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/graph.png (graph2use=flat, simple_form=True).

# %%
coreg_low_node.inputs.reference = nib_files[0]
coreg_low_node.inputs.in_file = nib_files[1]
coreg_full_node.inputs.reference = nib_files[0]
coreg_full_node.inputs.in_file = nib_files[2]
mask_node.inputs.in2 = nib_files[0]
masked_zero_node.inputs.input_file = nib_files[0]

# wf.run()
wf.run(plugin='MultiProc', plugin_args={'n_procs' : 8})
# Out:
# 190221-21:30:39,757 nipype.workflow INFO:
# 	 Workflow registration_no_bet settings: ['check', 'execution', 'logging', 'monitoring']
# 190221-21:30:39,775 nipype.workflow INFO:
# 	 Running in parallel.
# 190221-21:30:39,779 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 45.99/45.99, Free processors: 8/8.
# 190221-21:30:39,991 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.coreg_full" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/coreg_full".
# 190221-21:30:39,994 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.coreg_low" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/coreg_low".
# 190221-21:30:40,2 nipype.workflow INFO:
# 	 [Node] Running "coreg_full" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /raid/jon/data_full_stanford/data/Patient_0545/14_ax_bravoc.nii.gz -ref /raid/jon/data_full_stanford/data/Patient_0545/7_ax_bravo_pre.nii.gz -out 14_ax_bravoc_flirt.nii.gz -omat 14_ax_bravoc_flirt.mat -bins 256 -cost corratio -dof 6 -interp trilinear -searchrx -20 20 -searchry -20 20 -searchrz -20 20
# 190221-21:30:40,5 nipype.workflow INFO:
# 	 [Node] Running "coreg_low" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /raid/jon/data_full_stanford/data/Patient_0545/10_ax_bravo_c_pre_load_10.nii.gz -ref /raid/jon/data_full_stanford/data/Patient_0545/7_ax_bravo_pre.nii.gz -out 10_ax_bravo_c_pre_load_10_flirt.nii.gz -omat 10_ax_bravo_c_pre_load_10_flirt.mat -bins 256 -cost corratio -dof 6 -interp trilinear -searchrx -20 20 -searchry -20 20 -searchrz -20 20
# 190221-21:30:41,782 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 45.59/45.99, Free processors: 6/8.
#                      Currently running:
#                        * registration_no_bet.coreg_low
#                        * registration_no_bet.coreg_full
# 190221-21:38:08,213 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.coreg_low".
# 190221-21:38:10,195 nipype.workflow INFO:
# 	 [Job 1] Completed (registration_no_bet.coreg_low).
# 190221-21:38:10,203 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 45.79/45.99, Free processors: 7/8.
#                      Currently running:
#                        * registration_no_bet.coreg_full
# 190221-21:38:26,764 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.coreg_full".
# 190221-21:38:28,213 nipype.workflow INFO:
# 	 [Job 0] Completed (registration_no_bet.coreg_full).
# 190221-21:38:28,216 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 45.99/45.99, Free processors: 8/8.
# 190221-21:38:28,351 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.mask_combine" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/mask_combine".
# 190221-21:38:28,360 nipype.workflow INFO:
# 	 [Node] Running "mask_combine" ("__main__.MaskCombine")
# 190221-21:38:30,216 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 45.79/45.99, Free processors: 7/8.
#                      Currently running:
#                        * registration_no_bet.mask_combine
# 190221-21:38:36,209 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.mask_combine".
# 190221-21:38:36,221 nipype.workflow INFO:
# 	 [Job 2] Completed (registration_no_bet.mask_combine).
# 190221-21:38:36,224 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 45.99/45.99, Free processors: 8/8.
# 190221-21:38:36,363 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.masked_full" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/masked_full".
# 190221-21:38:36,365 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.masked_low" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/masked_low".190221-21:38:36,366 nipype.workflow INFO:
# 	 [Node] Setting-up "registration_no_bet.masked_zero" in "/raid/jon/data_full_stanford/data/Patient_0545/registration_no_bet/masked_zero".
#
# 190221-21:38:36,371 nipype.workflow INFO:
# 	 [Node] Running "masked_full" ("__main__.ApplyMask")
# 190221-21:38:36,376 nipype.workflow INFO:
# 	 [Node] Running "masked_zero" ("__main__.ApplyMask")190221-21:38:36,377 nipype.workflow INFO:
# 	 [Node] Running "masked_low" ("__main__.ApplyMask")
#
# 190221-21:38:38,225 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 45.39/45.99, Free processors: 5/8.
#                      Currently running:
#                        * registration_no_bet.masked_zero
#                        * registration_no_bet.masked_low
#                        * registration_no_bet.masked_full
# 190221-21:38:48,415 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.masked_full".
# 190221-21:38:48,443 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.masked_zero".
# 190221-21:38:48,575 nipype.workflow INFO:
# 	 [Node] Finished "registration_no_bet.masked_low".
# 190221-21:38:50,235 nipype.workflow INFO:
# 	 [Job 3] Completed (registration_no_bet.masked_full).
# 190221-21:38:50,238 nipype.workflow INFO:
# 	 [Job 4] Completed (registration_no_bet.masked_low).
# 190221-21:38:50,239 nipype.workflow INFO:
# 	 [Job 5] Completed (registration_no_bet.masked_zero).
# 190221-21:38:50,242 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 45.99/45.99, Free processors: 8/8.

# %%
print(working_dir)
# !tree /raid/jon/data_full_stanford/data/Patient_0545 -I '*js|*json|*html|*pklz|_report'
# Out:
# /raid/jon/data_full_stanford/data/Patient_0545
# /raid/jon/data_full_stanford/data/Patient_0545
# ├── 10_ax_bravo_c_pre_load_10.nii.gz
# ├── 14_ax_bravoc.nii.gz
# ├── 7_ax_bravo_pre.nii.gz
# ├── registration
# │   ├── bet_full
# │   │   ├── 14_ax_bravoc_brain.nii.gz
# │   │   └── command.txt
# │   ├── bet_low
# │   │   ├── 10_ax_bravo_c_pre_load_10_brain.nii.gz
# │   │   └── command.txt
# │   ├── bet_zero
# │   │   ├── 7_ax_bravo_pre_brain.nii.gz
# │   │   └── command.txt
# │   ├── coreg_full
# │   │   ├── 14_ax_bravoc_brain_flirt.nii.gz
# │   │   └── command.txt
# │   ├── coreg_low
# │   │   ├── 10_ax_bravo_c_pre_load_10_brain_flirt.nii.gz
# │   │   └── command.txt
# │   ├── graph.dot
# │   ├── graph.png
# │   ├── graph_detailed.dot
# │   ├── graph_detailed.png
# │   ├── mask_combine
# │   │   └── 14_ax_bravoc_brain_flirt_combined_mask.nii.gz
# │   ├── masked_full
# │   │   └── 14_ax_bravoc_brain_flirt_masked.nii.gz
# │   ├── masked_low
# │   │   └── 10_ax_bravo_c_pre_load_10_brain_flirt_masked.nii.gz
# │   └── masked_zero
# │       └── 7_ax_bravo_pre_brain_masked.nii.gz
# └── registration_no_bet
#     ├── coreg_full
#     │   ├── 14_ax_bravoc_flirt.nii.gz
#     │   └── command.txt
#     ├── coreg_low
#     │   ├── 10_ax_bravo_c_pre_load_10_flirt.nii.gz
#     │   └── command.txt
#     ├── graph.dot
#     ├── graph.png
#     ├── graph_detailed.dot
#     ├── graph_detailed.png
#     ├── mask_combine
#     │   └── 14_ax_bravoc_flirt_combined_mask.nii.gz
#     ├── masked_full
#     │   └── 14_ax_bravoc_flirt_masked.nii.gz
#     ├── masked_low
#     │   └── 10_ax_bravo_c_pre_load_10_flirt_masked.nii.gz
#     └── masked_zero
#         └── 7_ax_bravo_pre_masked.nii.gz
#
# 17 directories, 33 files

# %%
idx = 200
_tmp = nib.load('{}/registration_no_bet/masked_low/10_ax_bravo_c_pre_load_10_flirt_masked.nii.gz'.format(working_dir))
_tmp2 = nib.load('{}/registration_no_bet/coreg_low/10_ax_bravo_c_pre_load_10_flirt.nii.gz'.format(working_dir))
tmp2 = _tmp2.get_fdata()
tmp = _tmp.get_fdata()
print(tmp.shape)
plt.imshow(tmp[...,idx]>0)
plt.figure()
plt.imshow(tmp2[...,idx]>0)
plt.figure()
plt.imshow(((tmp>0)!=(tmp2>0))[...,idx])
# Out:
# (512, 512, 352)

# %%
_x0 = nib.load('{}/registration_no_bet/masked_zero/7_ax_bravo_pre_masked.nii.gz'.format(working_dir))
_x1 = nib.load('{}/registration_no_bet/masked_low/10_ax_bravo_c_pre_load_10_flirt_masked.nii.gz'.format(working_dir))
_x2 = nib.load('{}/registration_no_bet/masked_full/14_ax_bravoc_flirt_masked.nii.gz'.format(working_dir))

x0, x1, x2 = [__x.get_fdata() for __x in (_x0, _x1, _x2)]

# %%
idx = 150

plt.figure(figsize=(16,10))
plt.imshow(abs(x2[...,idx] - x0[...,idx]), cmap='gray')

plt.figure(figsize=(16,10))
suplot.imshowreg(x0[...,idx], x1[...,idx])

plt.figure(figsize=(16,10))
suplot.imshowreg(x0[...,idx], x2[...,idx])

# %% [markdown]
# ## test kmeans to make enhancement mask

# %%
from sklearn.cluster import KMeans

# %%
n = 6
idx_kmeans = np.arange(idx-20, idx+20)
X = np.stack((x0[...,idx_kmeans].ravel(), x1[...,idx_kmeans].ravel(), x2[...,idx_kmeans].ravel())).T
Xn = np.linalg.norm(X, axis=1)
print(X.shape)
X2 = X[Xn > 0.05*np.max(Xn)]
print(X2.shape)
kmeans = KMeans(n_clusters=n, random_state=723, n_jobs=10)
kmeans.fit(X2)
# Out:
# (10485760, 3)
# (4154767, 3)
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=10, precompute_distances='auto',
#     random_state=723, tol=0.0001, verbose=0)

# %%
Y = kmeans.predict(X).reshape((x0[...,idx_kmeans].shape)).squeeze()
print(Y.shape)
# Out:
# (512, 512, 40)

# %%
_idx = 0
plt.figure(figsize=(8,8))
plt.imshow(Y[...,_idx])
plt.figure(figsize=(8,8))
plt.imshow(x2[...,idx_kmeans[_idx]].squeeze())
plt.figure(figsize=(8,8))
plt.imshow(x2[...,idx_kmeans[_idx]].squeeze() * (Y[...,_idx]==5))

# it seems like it's simpler to threshold the difference image to get an enhancement mask
tmp = x2-x0
plt.figure(figsize=(8,8))
plt.imshow((tmp*(tmp > .05*np.max(abs(tmp))))[...,idx_kmeans[_idx]].squeeze())

# %%
import SimpleITK as sitk
import subtle.subtle_preprocess as supre

# %%
idx=150
plt.figure(figsize=(16,8))
suplot.imshowtile(np.stack((x0,x1,x2), axis=3)[:,:,idx,:].squeeze())

# %%
x2_sc = supre.scale_im_enhao(x0[...,idx-5:idx+5], x2[...,idx-5:idx+5])
print(x2_sc)
x2_scaled = x2 * x2_sc

x1_sc = supre.scale_im_enhao(x0[...,idx-5:idx+5], x1[...,idx-5:idx+5])
print(x1_sc)
x1_scaled = x1 * x2_sc

plt.figure(figsize=(16,8))
suplot.imshowtile(np.stack((x0,x1_scaled,x2_scaled), axis=3)[:,:,idx,:].squeeze())
# Out:
# 0.8
# 0.9655172413793103

# %%
x2_hist_scaled = supre.scale_im(x0, x2_scaled)
x1_hist_scaled = supre.scale_im(x0, x1_scaled)
plt.figure(figsize=(16,8))
suplot.imshowtile(np.stack((x0,x1_hist_scaled,x2_hist_scaled), axis=3)[:,:,idx,:].squeeze())
# Out:
# image intensity normalization
# scaling done, 7.54 s
# image intensity normalization
# scaling done, 7.49 s

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.imshow(abs(x1_scaled[...,idx] - x0[...,idx]), cmap='gray')

plt.subplot(1,2,2)
plt.imshow(abs(x2_scaled[...,idx] - x0[...,idx]), cmap='gray')


plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.imshow(abs(x1_hist_scaled[...,idx] - x0[...,idx]), cmap='gray')

plt.subplot(1,2,2)
plt.imshow(abs(x2_hist_scaled[...,idx] - x0[...,idx]), cmap='gray')

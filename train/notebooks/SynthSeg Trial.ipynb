# %%
import numpy as np
from subtle.utils.io import dicom_files, load_file

import matplotlib.pyplot as plt
from skimage.transform import resize
import nibabel as nib
plt.set_cmap('gray')
plt.rcParams['figure.figsize'] = (10, 8)
# Out:
# /home/srivathsa/projects/SubtleGad/train/subtle/utils/hyperparameter.py:8: UserWarning: Module test_tube not found - hyperparameter related functions cannot be used
#   warnings.warn('Module test_tube not found - hyperparameter related functions cannot be used')

# %%
dcm_vol, _ = dicom_files('/home/srivathsa/projects/studies/gad/stanford/data/Patient_0085/7_AX_BRAVO_PRE')
dcm_vol = np.transpose(dcm_vol, (2, 1, 0))
dcm_vol = np.rot90(dcm_vol, k=2)

# %%
np.savez('/home/srivathsa/projects/SynthSeg/data/sample/Patient_0085.npz', vol_data=dcm_vol)

# %%
data = nib.load('/home/srivathsa/projects/SynthSeg/data/training_label_maps/training_seg_01.nii.gz').get_data()
# Out:
# /home/srivathsa/miniconda3/envs/py35gad/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
import dicom2nifti
dicom2nifti.dicom_series_to_nifti(
    '/home/srivathsa/projects/studies/gad/stanford/data/Patient_0085/7_AX_BRAVO_PRE',
    '/home/srivathsa/projects/SynthSeg/data/sample/Patient_0085.nii.gz'
)
# Out:
# {'NII_FILE': '/home/srivathsa/projects/SynthSeg/data/sample/Patient_0085.nii.gz',
#  'NII': <nibabel.nifti1.Nifti1Image at 0x7f44ea3f22e8>,
#  'MAX_SLICE_INCREMENT': 0.5}

# %%
data = nib.load('/home/srivathsa/projects/SynthSeg/data/sample/BraTS2021_00389_t1.nii.gz').get_data()
# Out:
# /home/srivathsa/miniconda3/envs/py35gad/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
data.shape
# Out:
# (240, 240, 155)

# %%
plt.imshow(data[:, 137, :])

# %%
# seg = nib.load('/home/srivathsa/projects/SynthSeg/data/sample/BraTS2021_00006_t1.npz').get_data()
# print(seg.shape)

seg = np.load('/home/srivathsa/projects/SynthSeg/data/sample/BraTS2021_00389_t1.npz')['vol_data']

# %%
plt.imshow(seg[:, 137, :], cmap='prism')

# %% [markdown]
# ### Possible solutions
#
# - Take the difference between low and zero, do some binary erosion using a rectangle like selem and add it back to zero and call it low_mod. Use this for inference

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import subtle.utils.io as suio
from skimage.morphology import binary_erosion, rectangle
plt.rcParams['figure.figsize'] = (10, 8)
plt.set_cmap('gray')

# %%
data = suio.load_file('/home/srivathsa/projects/studies/gad/tiantan/preprocess/data/NO37.h5')
low_dose = data[:, 1, ...]
low_ax = low_dose.transpose(1, 0, 2)
low_ax = np.rot90(low_ax, k=3, axes=(1, 2))

# %%
zero_ax = data[:, 0, ...].transpose(1, 0, 2)
zero_ax = np.rot90(zero_ax, k=3, axes=(1, 2))

# %%
full_ax = data[:, 2, ...].transpose(1, 0, 2)
full_ax = np.rot90(full_ax, k=3, axes=(1, 2))

# %%
diff = low_ax[107] - zero_ax[107]
plt.imshow(diff)

# %%
plt.imshow(full_ax[107] - zero_ax[107])

# %%
import matplotlib.pyplot as plt
plt.set_cmap('gray')
plt.rcParams['figure.figsize'] = (10, 8)
import numpy as np
import os

# %%
case = 'Patient_0216'
base_path = '/home/srivathsa/projects/studies/gad/stanford/preprocess/data/hdbet_masks'

fpath_hdbet_mask = os.path.join(base_path, '{}/{}.npy'.format(base_path, case))
mask = np.load(fpath_hdbet_mask)

data = np.load(os.path.join(base_path.replace('/hdbet_masks', ''), '{}.npy'.format(case)))

data_masked = data[0, :, 2] * mask

# %%
plt.imshow(data_masked[187])

# %%
print(mask.shape)
print(data[0].shape)
# Out:
# (336, 512, 512)
# (336, 4, 512, 512)

# %%
mask_r = np.repeat(mask[:, np.newaxis, :, :], 4, axis=1)
new_data = mask_r * data[0]

# %%
new_data = np.load('/home/srivathsa/projects/studies/gad/stanford/preprocess/data/Patient_0085.npy')

# %%
plt.imshow(new_data[1, 180, 3])

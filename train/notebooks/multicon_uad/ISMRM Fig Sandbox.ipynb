# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
plt.set_cmap('gray')
plt.rcParams['figure.figsize'] = (15, 12)

# %%
base_path = '/home/srivathsa/projects/studies/gad/stanford/preprocess/data_256'
cnum = 'Patient_0187'

data = np.load('{}/{}.npy'.format(base_path, cnum))

plt.imshow(data[2, 85])

# %%
data = nib.load('/mnt/datasets/srivathsa/ADNI_FLAIR/normal/ADNI_002_S_0413_77367701-FLAIR.nii.gz').get_fdata()
print(data.shape)
plt.imshow(np.rot90(data[..., 147]))
# Out:
# (192, 256, 256)

# %%
data = np.load('/home/srivathsa/projects/studies/gad/stanford/preprocess/data_256/Patient_0267.npy')
data = data[:, :, 80:-20, 40:-40]
sl=35 #80, 35

plt.imshow(np.hstack([data[0, sl], data[1, sl], data[3, sl], 
                      data[4, sl]]))

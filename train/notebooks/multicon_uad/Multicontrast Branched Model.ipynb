# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import os
import json

from subtle.dnn.generators import GeneratorUNet2D, GeneratorBranchUNet2D, GeneratorFBoostUNet2D
import subtle.utils.io as suio
from subtle.data_loaders.slice_loader import SliceLoader
import subtle.subtle_loss as suloss
from subtle.dnn.helpers import clear_keras_memory, set_keras_memory
from keras.optimizers import Adam

from keract import get_activations, display_activations, display_heatmaps
from keras.utils.vis_utils import plot_model

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

plt.rcParams['figure.figsize'] = (10, 8)
plt.set_cmap('gray')

def transfer_weights(src_model, dest_model, branch_num):
    kw = 'b{}_'.format(branch_num)
    op_layer = 'branch{}_output'.format(branch_num)
    
    print('Transferring weights -> {}'.format(kw))
    src_layers = [l.name for l in src_model.model.layers]
    for idx, layer in enumerate(dest_model.model.layers):
        if kw not in layer.name:
            continue
        unet_name = layer.name.replace(kw, '')

        if unet_name in src_layers:
            lname = unet_name
            lname_orig = layer.name
            src_weights = src_model.model.layers[src_layers.index(unet_name)].get_weights()
            dest_model.model.layers[idx].set_weights(src_weights)
            dest_model.model.layers[idx].trainable = False
    dest_model.model.get_layer(op_layer).set_weights(src_model.model.get_layer('model_output').get_weights())
    dest_model.model.get_layer(op_layer).trainable = False
    return dest_model

# %%
clear_keras_memory()
set_keras_memory(1.0)

loss_function = suloss.mixed_loss(l1_lambda=1.0, ssim_lambda=0.0)
metrics_monitor = [suloss.l1_loss]

model_main = GeneratorFBoostUNet2D(
                num_channel_input=35, num_channel_output=1,
                img_rows=240, img_cols=240,
                loss_function=loss_function,
                metrics_monitor=metrics_monitor,
                lr_init=0.001,
                verbose=1,
                compile_model=False,
                model_config='base',
                fpaths_pre=[
                    '/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/enh_vgg.checkpoint',
                    '/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_t2.checkpoint',
                    '/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_fl.checkpoint',
                    '/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_uad.checkpoint'
                ]
            )

# %%
clear_keras_memory()
set_keras_memory(1.0)

loss_function = suloss.mixed_loss(l1_lambda=1.0, ssim_lambda=0.0)
metrics_monitor = [suloss.l1_loss]


model_main = GeneratorBranchUNet2D(
            num_channel_input=35, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='fusion_single_ch')

model_t1 = GeneratorUNet2D(
            num_channel_input=14, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='base',
            checkpoint_file='/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/enh_vgg.checkpoint')

model_t1.load_weights()

model_t2 = GeneratorUNet2D(num_channel_input=14, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='base',
            checkpoint_file='/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_t2.checkpoint')
model_t2.load_weights()

model_fl = GeneratorUNet2D(num_channel_input=14, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='base',
            checkpoint_file='/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_fl.checkpoint')
model_fl.load_weights()

model_uad = GeneratorUNet2D(num_channel_input=14, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='base',
            checkpoint_file='/home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_uad.checkpoint')
model_uad.load_weights()
# Out:
# Building branch_unet2d-fusion_single_ch model...
# inputs Tensor("model_input:0", shape=(?, 240, 240, 35), dtype=float32)
# t1 pre Tensor("t1_pre/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# t1 low Tensor("t1_low/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# t2 Tensor("t2/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# fl Tensor("fl/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# uad Tensor("uad/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# Tensor("relu_b1_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b1_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b1_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b1_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b1_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b1_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b1_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b1_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b1_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b1_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b1_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b1_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b1_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b1_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_b2_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b2_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b2_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b2_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b2_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b2_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b2_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b2_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b2_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b2_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b2_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b2_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b2_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b2_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_b3_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b3_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b3_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b3_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b3_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b3_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b3_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b3_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b3_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b3_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b3_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b3_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b3_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b3_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_b4_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b4_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b4_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b4_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b4_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b4_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b4_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b4_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b4_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b4_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b4_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b4_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b4_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b4_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_fbst_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("fbst_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_fbst_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("fbst_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_fbst_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("fbst_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_fbst_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("fbst_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_fbst_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("fbst_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_fbst_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("fbst_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_fbst_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("fbst_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("linear_model_output/Identity:0", shape=(?, 240, 240, 1), dtype=float32)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        (None, 240, 240, 35) 0
# __________________________________________________________________________________________________
# t1_pre (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t1_low (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t2 (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# fl (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# uad (Lambda)                    (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# branch_t1 (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  t1_low[0][0]
# __________________________________________________________________________________________________
# branch_t2 (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  t2[0][0]
# __________________________________________________________________________________________________
# branch_fl (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  fl[0][0]
# __________________________________________________________________________________________________
# branch_uad (Concatenate)        (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  uad[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_t1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_t2[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_fl[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_uad[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b3_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b4_maxpool_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b3_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b4_maxpool_2[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b2_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b3_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b3_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b4_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b4_maxpool_3[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_center (Activation (None, 30, 30, 128)  0           b1_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_center (Activation (None, 30, 30, 128)  0           b2_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_center (Activation (None, 30, 30, 128)  0           b3_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_center (Activation (None, 30, 30, 128)  0           b4_conv_center[0][0]
# __________________________________________________________________________________________________
# b1_add_center (Add)             (None, 30, 30, 128)  0           b1_maxpool_3[0][0]
#                                                                  relu_b1_conv_center[0][0]
# __________________________________________________________________________________________________
# b2_add_center (Add)             (None, 30, 30, 128)  0           b2_maxpool_3[0][0]
#                                                                  relu_b2_conv_center[0][0]
# __________________________________________________________________________________________________
# b3_add_center (Add)             (None, 30, 30, 128)  0           b3_maxpool_3[0][0]
#                                                                  relu_b3_conv_center[0][0]
# __________________________________________________________________________________________________
# b4_add_center (Add)             (None, 30, 30, 128)  0           b4_maxpool_3[0][0]
#                                                                  relu_b4_conv_center[0][0]
# __________________________________________________________________________________________________
# b1_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b1_add_center[0][0]
# __________________________________________________________________________________________________
# b2_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b2_add_center[0][0]
# __________________________________________________________________________________________________
# b3_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b3_add_center[0][0]
# __________________________________________________________________________________________________
# b4_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b4_add_center[0][0]
# __________________________________________________________________________________________________
# b1_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b1_upsample_2[0][0]
#                                                                  relu_b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b2_upsample_2[0][0]
#                                                                  relu_b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b3_upsample_2[0][0]
#                                                                  relu_b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b4_upsample_2[0][0]
#                                                                  relu_b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b1_cat_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b2_cat_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b3_cat_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b4_cat_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b1_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b1_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b2_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b2_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b3_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b3_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b4_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b4_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b1_cat_2 (Concatenate)          (None, 120, 120, 192 0           b1_upsample_3[0][0]
#                                                                  relu_b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_2 (Concatenate)          (None, 120, 120, 192 0           b2_upsample_3[0][0]
#                                                                  relu_b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_2 (Concatenate)          (None, 120, 120, 192 0           b3_upsample_3[0][0]
#                                                                  relu_b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_2 (Concatenate)          (None, 120, 120, 192 0           b4_upsample_3[0][0]
#                                                                  relu_b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b1_cat_2[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b2_cat_2[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b3_cat_2[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b4_cat_2[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b1_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b1_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b2_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b2_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b3_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b3_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b4_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b4_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b1_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b1_upsample_4[0][0]
#                                                                  relu_b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b2_upsample_4[0][0]
#                                                                  relu_b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b3_upsample_4[0][0]
#                                                                  relu_b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b4_upsample_4[0][0]
#                                                                  relu_b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b1_cat_3[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b2_cat_3[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b3_cat_3[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b4_cat_3[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b4_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b4_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_2[0][0]
# ...
# conv_dec_3_0 (Conv2D)           (None, 120, 120, 64) 110656      cat_2[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_0 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# conv_dec_3_1 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_1 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# conv_dec_3_2 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_2 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# upsample_4 (UpSampling2D)       (None, 240, 240, 64) 0           relu_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# cat_3 (Concatenate)             (None, 240, 240, 96) 0           upsample_4[0][0]
#                                                                  relu_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_0 (Conv2D)           (None, 240, 240, 32) 27680       cat_3[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_0 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_1 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_1 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_2 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_2 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# model_output (Conv2D)           (None, 240, 240, 1)  33          relu_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# linear_model_output (Activation (None, 240, 240, 1)  0           model_output[0][0]
# ==================================================================================================
# Total params: 1,452,449
# Trainable params: 1,452,449
# Non-trainable params: 0
# __________________________________________________________________________________________________
# <keras.engine.training.Model object at 0x7f04f43fd550>
# loading weights from /home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_fl.checkpoint
# Building unet2d model...
# Tensor("model_input_4:0", shape=(?, 240, 240, 14), dtype=float32)
# Tensor("relu_conv_enc_1_2_3/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("maxpool_1_3/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_conv_enc_2_2_3/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("maxpool_2_3/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_conv_enc_3_2_3/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("maxpool_3_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_conv_center_3/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("add_center_3/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_conv_dec_2_2_3/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("cat_1_3/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_conv_dec_3_2_3/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("cat_2_3/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_conv_dec_4_2_3/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("cat_3_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("linear_model_output_4/Identity:0", shape=(?, 240, 240, 1), dtype=float32)
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        (None, 240, 240, 14) 0
# __________________________________________________________________________________________________
# conv_enc_1_0 (Conv2D)           (None, 240, 240, 32) 4064        model_input[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_1_0 (Activation)  (None, 240, 240, 32) 0           conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# conv_enc_1_1 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_1_1 (Activation)  (None, 240, 240, 32) 0           conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# conv_enc_1_2 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_1_2 (Activation)  (None, 240, 240, 32) 0           conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# maxpool_1 (MaxPooling2D)        (None, 120, 120, 32) 0           relu_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# conv_enc_2_0 (Conv2D)           (None, 120, 120, 64) 18496       maxpool_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_2_0 (Activation)  (None, 120, 120, 64) 0           conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# conv_enc_2_1 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_2_1 (Activation)  (None, 120, 120, 64) 0           conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# conv_enc_2_2 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_2_2 (Activation)  (None, 120, 120, 64) 0           conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# maxpool_2 (MaxPooling2D)        (None, 60, 60, 64)   0           relu_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# conv_enc_3_0 (Conv2D)           (None, 60, 60, 128)  73856       maxpool_2[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_3_0 (Activation)  (None, 60, 60, 128)  0           conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# conv_enc_3_1 (Conv2D)           (None, 60, 60, 128)  147584      relu_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_3_1 (Activation)  (None, 60, 60, 128)  0           conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# conv_enc_3_2 (Conv2D)           (None, 60, 60, 128)  147584      relu_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_enc_3_2 (Activation)  (None, 60, 60, 128)  0           conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# maxpool_3 (MaxPooling2D)        (None, 30, 30, 128)  0           relu_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# conv_center (Conv2D)            (None, 30, 30, 128)  147584      maxpool_3[0][0]
# __________________________________________________________________________________________________
# relu_conv_center (Activation)   (None, 30, 30, 128)  0           conv_center[0][0]
# __________________________________________________________________________________________________
# add_center (Add)                (None, 30, 30, 128)  0           maxpool_3[0][0]
#                                                                  relu_conv_center[0][0]
# __________________________________________________________________________________________________
# upsample_2 (UpSampling2D)       (None, 60, 60, 128)  0           add_center[0][0]
# __________________________________________________________________________________________________
# cat_1 (Concatenate)             (None, 60, 60, 256)  0           upsample_2[0][0]
#                                                                  relu_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# conv_dec_2_0 (Conv2D)           (None, 60, 60, 128)  295040      cat_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_2_0 (Activation)  (None, 60, 60, 128)  0           conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# conv_dec_2_1 (Conv2D)           (None, 60, 60, 128)  147584      relu_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_2_1 (Activation)  (None, 60, 60, 128)  0           conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# conv_dec_2_2 (Conv2D)           (None, 60, 60, 128)  147584      relu_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_2_2 (Activation)  (None, 60, 60, 128)  0           conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# upsample_3 (UpSampling2D)       (None, 120, 120, 128 0           relu_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# cat_2 (Concatenate)             (None, 120, 120, 192 0           upsample_3[0][0]
#                                                                  relu_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# conv_dec_3_0 (Conv2D)           (None, 120, 120, 64) 110656      cat_2[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_0 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# conv_dec_3_1 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_1 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# conv_dec_3_2 (Conv2D)           (None, 120, 120, 64) 36928       relu_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_3_2 (Activation)  (None, 120, 120, 64) 0           conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# upsample_4 (UpSampling2D)       (None, 240, 240, 64) 0           relu_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# cat_3 (Concatenate)             (None, 240, 240, 96) 0           upsample_4[0][0]
#                                                                  relu_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_0 (Conv2D)           (None, 240, 240, 32) 27680       cat_3[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_0 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_1 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_1 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# conv_dec_4_2 (Conv2D)           (None, 240, 240, 32) 9248        relu_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_conv_dec_4_2 (Activation)  (None, 240, 240, 32) 0           conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# model_output (Conv2D)           (None, 240, 240, 1)  33          relu_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# linear_model_output (Activation (None, 240, 240, 1)  0           model_output[0][0]
# ==================================================================================================
# Total params: 1,452,449
# Trainable params: 1,452,449
# Non-trainable params: 0
# __________________________________________________________________________________________________
# <keras.engine.training.Model object at 0x7f04e021d780>
# loading weights from /home/srivathsa/projects/studies/gad/tiantan/train/checkpoints/fboost_t1_uad.checkpoint

# %%
model_main = transfer_weights(model_t1, model_main, '1')
model_main = transfer_weights(model_t2, model_main, '2')
model_main = transfer_weights(model_fl, model_main, '3')
model_main = transfer_weights(model_uad, model_main, '4')
# Out:
# Transferring weights -> b1_
# Transferring weights -> b2_
# Transferring weights -> b3_
# Transferring weights -> b4_

# %%
model_main.model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        (None, 240, 240, 35) 0
# __________________________________________________________________________________________________
# t1_pre (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t1_low (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t2 (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# fl (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# uad (Lambda)                    (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# branch_t1 (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  t1_low[0][0]
# __________________________________________________________________________________________________
# branch_t2 (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  t2[0][0]
# __________________________________________________________________________________________________
# branch_fl (Concatenate)         (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  fl[0][0]
# __________________________________________________________________________________________________
# branch_uad (Concatenate)        (None, 240, 240, 14) 0           t1_pre[0][0]
#                                                                  uad[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_t1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_t2[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_fl[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_0 (Conv2D)        (None, 240, 240, 32) 4064        branch_uad[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_0 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_1 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_1_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_1_2 (Activatio (None, 240, 240, 32) 0           b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_1 (MaxPooling2D)     (None, 120, 120, 32) 0           relu_b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b3_maxpool_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_0 (Conv2D)        (None, 120, 120, 64) 18496       b4_maxpool_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_0 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_1 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_2_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_2_2 (Activatio (None, 120, 120, 64) 0           b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_2 (MaxPooling2D)     (None, 60, 60, 64)   0           relu_b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b3_maxpool_2[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_0 (Conv2D)        (None, 60, 60, 128)  73856       b4_maxpool_2[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_0 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_1 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_enc_3_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_enc_3_2 (Activatio (None, 60, 60, 128)  0           b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b2_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b3_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b4_maxpool_3 (MaxPooling2D)     (None, 30, 30, 128)  0           relu_b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b2_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b3_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b3_maxpool_3[0][0]
# __________________________________________________________________________________________________
# b4_conv_center (Conv2D)         (None, 30, 30, 128)  147584      b4_maxpool_3[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_center (Activation (None, 30, 30, 128)  0           b1_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_center (Activation (None, 30, 30, 128)  0           b2_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_center (Activation (None, 30, 30, 128)  0           b3_conv_center[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_center (Activation (None, 30, 30, 128)  0           b4_conv_center[0][0]
# __________________________________________________________________________________________________
# b1_add_center (Add)             (None, 30, 30, 128)  0           b1_maxpool_3[0][0]
#                                                                  relu_b1_conv_center[0][0]
# __________________________________________________________________________________________________
# b2_add_center (Add)             (None, 30, 30, 128)  0           b2_maxpool_3[0][0]
#                                                                  relu_b2_conv_center[0][0]
# __________________________________________________________________________________________________
# b3_add_center (Add)             (None, 30, 30, 128)  0           b3_maxpool_3[0][0]
#                                                                  relu_b3_conv_center[0][0]
# __________________________________________________________________________________________________
# b4_add_center (Add)             (None, 30, 30, 128)  0           b4_maxpool_3[0][0]
#                                                                  relu_b4_conv_center[0][0]
# __________________________________________________________________________________________________
# b1_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b1_add_center[0][0]
# __________________________________________________________________________________________________
# b2_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b2_add_center[0][0]
# __________________________________________________________________________________________________
# b3_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b3_add_center[0][0]
# __________________________________________________________________________________________________
# b4_upsample_2 (UpSampling2D)    (None, 60, 60, 128)  0           b4_add_center[0][0]
# __________________________________________________________________________________________________
# b1_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b1_upsample_2[0][0]
#                                                                  relu_b1_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b2_upsample_2[0][0]
#                                                                  relu_b2_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b3_upsample_2[0][0]
#                                                                  relu_b3_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_1 (Concatenate)          (None, 60, 60, 256)  0           b4_upsample_2[0][0]
#                                                                  relu_b4_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b1_cat_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b2_cat_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b3_cat_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_0 (Conv2D)        (None, 60, 60, 128)  295040      b4_cat_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_0 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_1 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_1 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b1_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b2_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b3_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_2_2 (Conv2D)        (None, 60, 60, 128)  147584      relu_b4_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b1_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b2_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b3_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_2_2 (Activatio (None, 60, 60, 128)  0           b4_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b1_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b1_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b2_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b2_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b3_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b3_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b4_upsample_3 (UpSampling2D)    (None, 120, 120, 128 0           relu_b4_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# b1_cat_2 (Concatenate)          (None, 120, 120, 192 0           b1_upsample_3[0][0]
#                                                                  relu_b1_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_2 (Concatenate)          (None, 120, 120, 192 0           b2_upsample_3[0][0]
#                                                                  relu_b2_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_2 (Concatenate)          (None, 120, 120, 192 0           b3_upsample_3[0][0]
#                                                                  relu_b3_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_2 (Concatenate)          (None, 120, 120, 192 0           b4_upsample_3[0][0]
#                                                                  relu_b4_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b1_cat_2[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b2_cat_2[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b3_cat_2[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_0 (Conv2D)        (None, 120, 120, 64) 110656      b4_cat_2[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_0 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_1 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_1 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b1_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b2_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b3_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_3_2 (Conv2D)        (None, 120, 120, 64) 36928       relu_b4_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b1_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b2_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b3_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_3_2 (Activatio (None, 120, 120, 64) 0           b4_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b1_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b1_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b2_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b2_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b3_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b3_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b4_upsample_4 (UpSampling2D)    (None, 240, 240, 64) 0           relu_b4_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# b1_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b1_upsample_4[0][0]
#                                                                  relu_b1_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b2_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b2_upsample_4[0][0]
#                                                                  relu_b2_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b3_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b3_upsample_4[0][0]
#                                                                  relu_b3_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b4_cat_3 (Concatenate)          (None, 240, 240, 96) 0           b4_upsample_4[0][0]
#                                                                  relu_b4_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b1_cat_3[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b2_cat_3[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b3_cat_3[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_0 (Conv2D)        (None, 240, 240, 32) 27680       b4_cat_3[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_4_0 (Activatio (None, 240, 240, 32) 0           b4_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_1 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_4_1 (Activatio (None, 240, 240, 32) 0           b4_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b1_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b1_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b2_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b2_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b3_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b3_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# b4_conv_dec_4_2 (Conv2D)        (None, 240, 240, 32) 9248        relu_b4_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_b1_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b1_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# relu_b2_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b2_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# relu_b3_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b3_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# relu_b4_conv_dec_4_2 (Activatio (None, 240, 240, 32) 0           b4_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# branch1_output (Conv2D)         (None, 240, 240, 1)  33          relu_b1_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# branch2_output (Conv2D)         (None, 240, 240, 1)  33          relu_b2_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# branch3_output (Conv2D)         (None, 240, 240, 1)  33          relu_b3_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# branch4_output (Conv2D)         (None, 240, 240, 1)  33          relu_b4_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# linear_branch1_output (Activati (None, 240, 240, 1)  0           branch1_output[0][0]
# __________________________________________________________________________________________________
# linear_branch2_output (Activati (None, 240, 240, 1)  0           branch2_output[0][0]
# __________________________________________________________________________________________________
# linear_branch3_output (Activati (None, 240, 240, 1)  0           branch3_output[0][0]
# __________________________________________________________________________________________________
# linear_branch4_output (Activati (None, 240, 240, 1)  0           branch4_output[0][0]
# __________________________________________________________________________________________________
# fusion_boost_avg (Average)      (None, 240, 240, 1)  0           linear_branch1_output[0][0]
#                                                                  linear_branch2_output[0][0]
#                                                                  linear_branch3_output[0][0]
#                                                                  linear_branch4_output[0][0]
# __________________________________________________________________________________________________
# fboost (Concatenate)            (None, 240, 240, 8)  0           t1_pre[0][0]
#                                                                  fusion_boost_avg[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_1_0 (Conv2D)      (None, 240, 240, 32) 2336        fboost[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_1_0 (Activat (None, 240, 240, 32) 0           fbst_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_1_1 (Conv2D)      (None, 240, 240, 32) 9248        relu_fbst_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_1_1 (Activat (None, 240, 240, 32) 0           fbst_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_1_2 (Conv2D)      (None, 240, 240, 32) 9248        relu_fbst_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_1_2 (Activat (None, 240, 240, 32) 0           fbst_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# fbst_maxpool_1 (MaxPooling2D)   (None, 120, 120, 32) 0           relu_fbst_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_2_0 (Conv2D)      (None, 120, 120, 64) 18496       fbst_maxpool_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_2_0 (Activat (None, 120, 120, 64) 0           fbst_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_2_1 (Conv2D)      (None, 120, 120, 64) 36928       relu_fbst_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_2_1 (Activat (None, 120, 120, 64) 0           fbst_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_2_2 (Conv2D)      (None, 120, 120, 64) 36928       relu_fbst_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_2_2 (Activat (None, 120, 120, 64) 0           fbst_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# fbst_maxpool_2 (MaxPooling2D)   (None, 60, 60, 64)   0           relu_fbst_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_3_0 (Conv2D)      (None, 60, 60, 128)  73856       fbst_maxpool_2[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_3_0 (Activat (None, 60, 60, 128)  0           fbst_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_3_1 (Conv2D)      (None, 60, 60, 128)  147584      relu_fbst_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_3_1 (Activat (None, 60, 60, 128)  0           fbst_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_enc_3_2 (Conv2D)      (None, 60, 60, 128)  147584      relu_fbst_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_enc_3_2 (Activat (None, 60, 60, 128)  0           fbst_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# fbst_maxpool_3 (MaxPooling2D)   (None, 30, 30, 128)  0           relu_fbst_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_center (Conv2D)       (None, 30, 30, 128)  147584      fbst_maxpool_3[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_center (Activati (None, 30, 30, 128)  0           fbst_conv_center[0][0]
# __________________________________________________________________________________________________
# fbst_add_center (Add)           (None, 30, 30, 128)  0           fbst_maxpool_3[0][0]
#                                                                  relu_fbst_conv_center[0][0]
# __________________________________________________________________________________________________
# fbst_upsample_2 (UpSampling2D)  (None, 60, 60, 128)  0           fbst_add_center[0][0]
# __________________________________________________________________________________________________
# fbst_cat_1 (Concatenate)        (None, 60, 60, 256)  0           fbst_upsample_2[0][0]
#                                                                  relu_fbst_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_2_0 (Conv2D)      (None, 60, 60, 128)  295040      fbst_cat_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_2_0 (Activat (None, 60, 60, 128)  0           fbst_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_2_1 (Conv2D)      (None, 60, 60, 128)  147584      relu_fbst_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_2_1 (Activat (None, 60, 60, 128)  0           fbst_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_2_2 (Conv2D)      (None, 60, 60, 128)  147584      relu_fbst_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_2_2 (Activat (None, 60, 60, 128)  0           fbst_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# fbst_upsample_3 (UpSampling2D)  (None, 120, 120, 128 0           relu_fbst_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# fbst_cat_2 (Concatenate)        (None, 120, 120, 192 0           fbst_upsample_3[0][0]
#                                                                  relu_fbst_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_3_0 (Conv2D)      (None, 120, 120, 64) 110656      fbst_cat_2[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_3_0 (Activat (None, 120, 120, 64) 0           fbst_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_3_1 (Conv2D)      (None, 120, 120, 64) 36928       relu_fbst_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_3_1 (Activat (None, 120, 120, 64) 0           fbst_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_3_2 (Conv2D)      (None, 120, 120, 64) 36928       relu_fbst_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_3_2 (Activat (None, 120, 120, 64) 0           fbst_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# fbst_upsample_4 (UpSampling2D)  (None, 240, 240, 64) 0           relu_fbst_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# fbst_cat_3 (Concatenate)        (None, 240, 240, 96) 0           fbst_upsample_4[0][0]
#                                                                  relu_fbst_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_4_0 (Conv2D)      (None, 240, 240, 32) 27680       fbst_cat_3[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_4_0 (Activat (None, 240, 240, 32) 0           fbst_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_4_1 (Conv2D)      (None, 240, 240, 32) 9248        relu_fbst_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_4_1 (Activat (None, 240, 240, 32) 0           fbst_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# fbst_conv_dec_4_2 (Conv2D)      (None, 240, 240, 32) 9248        relu_fbst_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_fbst_conv_dec_4_2 (Activat (None, 240, 240, 32) 0           fbst_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# model_output (Conv2D)           (None, 240, 240, 1)  33          relu_fbst_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# linear_model_output (Activation (None, 240, 240, 1)  0           model_output[0][0]
# ==================================================================================================
# Total params: 7,260,517
# Trainable params: 1,450,721
# Non-trainable params: 5,809,796
# __________________________________________________________________________________________________

# %%
# model_main = transfer_weights(model_t1, model_main, 'fbst_')

# %%
prediction_generator = SliceLoader(
    data_list=['/home/srivathsa/projects/studies/gad/tiantan/preprocess/data_t2_fl/NO6.h5'],
    file_ext='h5',
    input_idx=[0, 1, 3, 4],
    output_idx=[2],
    batch_size=1,
    shuffle=False,
    verbose=0,
    residual_mode=False,
    slices_per_input=7,
    num_channel_output=1,
    resize=240,
    slice_axis=[0],
    brain_only=False,
    predict=False,
    use_enh_uad=True,
    use_uad_ch_input=True,
    uad_ip_channels=7,
    brain_only_mode=None,
    enh_mask_t2=False,
    enh_pfactor=1,
    fpath_uad_masks=['/home/srivathsa/projects/studies/gad/tiantan/preprocess/uad_masks_fl/NO6.npy'],
    uad_file_ext='npy'
)

# %%
y_pred = model_main.model.predict_generator(
    generator=prediction_generator,
    max_queue_size=16,
    workers=1,
    use_multiprocessing=False,
    verbose=0
)
print(y_pred.shape)

# %%
net_ip, op = prediction_generator.__getitem__(131)
print(net_ip.shape)
print(op.shape)
lname = 'fusion_boost_avg'
activations = get_activations(model_main.model, net_ip, layer_name=lname)[lname]
print(activations.shape)

# %%
plt.imshow(np.hstack([net_ip[0, ..., 15], activations[0, ..., 0], op[0, ..., 0]]))

# %%
plt.imshow(activations[0, ..., 0])

# %%
clear_keras_memory()
set_keras_memory(1.0)

loss_function = suloss.mixed_loss(l1_lambda=1.0, ssim_lambda=0.0)
metrics_monitor = [suloss.l1_loss]

model_br = GeneratorBranchUNet2D(
            num_channel_input=35, num_channel_output=1,
            img_rows=240, img_cols=240,
            loss_function=loss_function,
            metrics_monitor=metrics_monitor,
            lr_init=0.001,
            verbose=1,
            compile_model=False,
            model_config='simple_weighted')
# Out:
# Building branch_unet2d-simple_weighted model...
# inputs Tensor("model_input:0", shape=(?, 240, 240, 35), dtype=float32)
# t1 pre Tensor("t1_pre/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# t1 low Tensor("t1_low/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# t2 Tensor("t2/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# fl Tensor("fl/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# uad Tensor("uad/strided_slice:0", shape=(?, 240, 240, 7), dtype=float32)
# Tensor("relu_b1_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b1_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b1_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b1_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b1_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b1_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b1_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b1_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b1_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b1_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b1_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b1_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b1_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b1_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_b2_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b2_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b2_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b2_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b2_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b2_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b2_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b2_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b2_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b2_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b2_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b2_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b2_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b2_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("relu_b3_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b3_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_b3_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b3_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_b3_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b3_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_b3_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("b3_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_b3_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("b3_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_b3_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("b3_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_b3_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("b3_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# tracking <tf.Variable 'Variable:0' shape=(1, 1, 4) dtype=float32_ref> W
# Tensor("relu_wavg_conv_enc_1_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("wavg_maxpool_1/MaxPool:0", shape=(?, 120, 120, 32), dtype=float32)
# Tensor("relu_wavg_conv_enc_2_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("wavg_maxpool_2/MaxPool:0", shape=(?, 60, 60, 64), dtype=float32)
# Tensor("relu_wavg_conv_enc_3_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("wavg_maxpool_3/MaxPool:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center before add Tensor("relu_wavg_conv_center/Relu:0", shape=(?, 30, 30, 128), dtype=float32)
# conv center... Tensor("wavg_add_center/add:0", shape=(?, 30, 30, 128), dtype=float32)
# Tensor("relu_wavg_conv_dec_2_2/Relu:0", shape=(?, 60, 60, 128), dtype=float32) Tensor("wavg_cat_1/concat:0", shape=(?, 60, 60, 256), dtype=float32)
# Tensor("relu_wavg_conv_dec_3_2/Relu:0", shape=(?, 120, 120, 64), dtype=float32) Tensor("wavg_cat_2/concat:0", shape=(?, 120, 120, 192), dtype=float32)
# Tensor("relu_wavg_conv_dec_4_2/Relu:0", shape=(?, 240, 240, 32), dtype=float32) Tensor("wavg_cat_3/concat:0", shape=(?, 240, 240, 96), dtype=float32)
# Tensor("linear_model_output/Identity:0", shape=(?, 240, 240, 1), dtype=float32)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        (None, 240, 240, 35) 0
# __________________________________________________________________________________________________
# t1_pre (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t1_low (Lambda)                 (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# t2 (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# fl (Lambda)                     (None, 240, 240, 7)  0           model_input[0][0]
# __________________________________________________________________________________________________
# wavg_op (WeightedAverage)       [(None, 240, 240, 7) 4           t1_pre[0][0]
#                                                                  t1_low[0][0]
#                                                                  t2[0][0]
#                                                                  fl[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_1_0 (Conv2D)      (None, 240, 240, 32) 2048        wavg_op[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_1_0 (Activat (None, 240, 240, 32) 0           wavg_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_1_1 (Conv2D)      (None, 240, 240, 32) 9248        relu_wavg_conv_enc_1_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_1_1 (Activat (None, 240, 240, 32) 0           wavg_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_1_2 (Conv2D)      (None, 240, 240, 32) 9248        relu_wavg_conv_enc_1_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_1_2 (Activat (None, 240, 240, 32) 0           wavg_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# wavg_maxpool_1 (MaxPooling2D)   (None, 120, 120, 32) 0           relu_wavg_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_2_0 (Conv2D)      (None, 120, 120, 64) 18496       wavg_maxpool_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_2_0 (Activat (None, 120, 120, 64) 0           wavg_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_2_1 (Conv2D)      (None, 120, 120, 64) 36928       relu_wavg_conv_enc_2_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_2_1 (Activat (None, 120, 120, 64) 0           wavg_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_2_2 (Conv2D)      (None, 120, 120, 64) 36928       relu_wavg_conv_enc_2_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_2_2 (Activat (None, 120, 120, 64) 0           wavg_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# wavg_maxpool_2 (MaxPooling2D)   (None, 60, 60, 64)   0           relu_wavg_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_3_0 (Conv2D)      (None, 60, 60, 128)  73856       wavg_maxpool_2[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_3_0 (Activat (None, 60, 60, 128)  0           wavg_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_3_1 (Conv2D)      (None, 60, 60, 128)  147584      relu_wavg_conv_enc_3_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_3_1 (Activat (None, 60, 60, 128)  0           wavg_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_enc_3_2 (Conv2D)      (None, 60, 60, 128)  147584      relu_wavg_conv_enc_3_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_enc_3_2 (Activat (None, 60, 60, 128)  0           wavg_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# wavg_maxpool_3 (MaxPooling2D)   (None, 30, 30, 128)  0           relu_wavg_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_center (Conv2D)       (None, 30, 30, 128)  147584      wavg_maxpool_3[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_center (Activati (None, 30, 30, 128)  0           wavg_conv_center[0][0]
# __________________________________________________________________________________________________
# wavg_add_center (Add)           (None, 30, 30, 128)  0           wavg_maxpool_3[0][0]
#                                                                  relu_wavg_conv_center[0][0]
# __________________________________________________________________________________________________
# wavg_upsample_2 (UpSampling2D)  (None, 60, 60, 128)  0           wavg_add_center[0][0]
# __________________________________________________________________________________________________
# wavg_cat_1 (Concatenate)        (None, 60, 60, 256)  0           wavg_upsample_2[0][0]
#                                                                  relu_wavg_conv_enc_3_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_2_0 (Conv2D)      (None, 60, 60, 128)  295040      wavg_cat_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_2_0 (Activat (None, 60, 60, 128)  0           wavg_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_2_1 (Conv2D)      (None, 60, 60, 128)  147584      relu_wavg_conv_dec_2_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_2_1 (Activat (None, 60, 60, 128)  0           wavg_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_2_2 (Conv2D)      (None, 60, 60, 128)  147584      relu_wavg_conv_dec_2_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_2_2 (Activat (None, 60, 60, 128)  0           wavg_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# wavg_upsample_3 (UpSampling2D)  (None, 120, 120, 128 0           relu_wavg_conv_dec_2_2[0][0]
# __________________________________________________________________________________________________
# wavg_cat_2 (Concatenate)        (None, 120, 120, 192 0           wavg_upsample_3[0][0]
#                                                                  relu_wavg_conv_enc_2_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_3_0 (Conv2D)      (None, 120, 120, 64) 110656      wavg_cat_2[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_3_0 (Activat (None, 120, 120, 64) 0           wavg_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_3_1 (Conv2D)      (None, 120, 120, 64) 36928       relu_wavg_conv_dec_3_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_3_1 (Activat (None, 120, 120, 64) 0           wavg_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_3_2 (Conv2D)      (None, 120, 120, 64) 36928       relu_wavg_conv_dec_3_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_3_2 (Activat (None, 120, 120, 64) 0           wavg_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# wavg_upsample_4 (UpSampling2D)  (None, 240, 240, 64) 0           relu_wavg_conv_dec_3_2[0][0]
# __________________________________________________________________________________________________
# wavg_cat_3 (Concatenate)        (None, 240, 240, 96) 0           wavg_upsample_4[0][0]
#                                                                  relu_wavg_conv_enc_1_2[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_4_0 (Conv2D)      (None, 240, 240, 32) 27680       wavg_cat_3[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_4_0 (Activat (None, 240, 240, 32) 0           wavg_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_4_1 (Conv2D)      (None, 240, 240, 32) 9248        relu_wavg_conv_dec_4_0[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_4_1 (Activat (None, 240, 240, 32) 0           wavg_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# wavg_conv_dec_4_2 (Conv2D)      (None, 240, 240, 32) 9248        relu_wavg_conv_dec_4_1[0][0]
# __________________________________________________________________________________________________
# relu_wavg_conv_dec_4_2 (Activat (None, 240, 240, 32) 0           wavg_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# model_output (Conv2D)           (None, 240, 240, 1)  33          relu_wavg_conv_dec_4_2[0][0]
# __________________________________________________________________________________________________
# linear_model_output (Activation (None, 240, 240, 1)  0           model_output[0][0]
# ==================================================================================================
# Total params: 1,450,437
# Trainable params: 1,450,437
# Non-trainable params: 0
# __________________________________________________________________________________________________
# <keras.engine.training.Model object at 0x7f053c7a3be0>

# %%
model_br.model._updated_config()
# Out:
# {'class_name': 'Model',
#  'config': {'name': 'model_1',
#   'layers': [{'name': 'model_input',
#     'class_name': 'InputLayer',
#     'config': {'batch_input_shape': (None, 240, 240, 35),
#      'dtype': 'float32',
#      'sparse': False,
#      'name': 'model_input'},
#     'inbound_nodes': []},
#    {'name': 't1_pre',
#     'class_name': 'Lambda',
#     'config': {'name': 't1_pre',
#      'trainable': True,
#      'dtype': 'float32',
#      'function': ('4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\nAABzAAAAAA==\n',
#       None,
#       (4, 5)),
#      'function_type': 'lambda',
#      'output_shape': None,
#      'output_shape_type': 'raw',
#      'arguments': {}},
#     'inbound_nodes': [[['model_input', 0, 0, {}]]]},
#    {'name': 't1_low',
#     'class_name': 'Lambda',
#     'config': {'name': 't1_low',
#      'trainable': True,
#      'dtype': 'float32',
#      'function': ('4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\nAABzAAAAAA==\n',
#       None,
#       (4, 5)),
#      'function_type': 'lambda',
#      'output_shape': None,
#      'output_shape_type': 'raw',
#      'arguments': {}},
#     'inbound_nodes': [[['model_input', 0, 0, {}]]]},
#    {'name': 't2',
#     'class_name': 'Lambda',
#     'config': {'name': 't2',
#      'trainable': True,
#      'dtype': 'float32',
#      'function': ('4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\nAABzAAAAAA==\n',
#       None,
#       (4, 5)),
#      'function_type': 'lambda',
#      'output_shape': None,
#      'output_shape_type': 'raw',
#      'arguments': {}},
#     'inbound_nodes': [[['model_input', 0, 0, {}]]]},
#    {'name': 'fl',
#     'class_name': 'Lambda',
#     'config': {'name': 'fl',
#      'trainable': True,
#      'dtype': 'float32',
#      'function': ('4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\nAABzAAAAAA==\n',
#       None,
#       (4, 5)),
#      'function_type': 'lambda',
#      'output_shape': None,
#      'output_shape_type': 'raw',
#      'arguments': {}},
#     'inbound_nodes': [[['model_input', 0, 0, {}]]]},
#    {'name': 'uad',
#     'class_name': 'Lambda',
#     'config': {'name': 'uad',
#      'trainable': True,
#      'dtype': 'float32',
#      'function': ('4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\nAABzAAAAAA==\n',
#       None,
#       (4, 5)),
#      'function_type': 'lambda',
#      'output_shape': None,
#      'output_shape_type': 'raw',
#      'arguments': {}},
#     'inbound_nodes': [[['model_input', 0, 0, {}]]]},
#    {'name': 'branch_t1',
#     'class_name': 'Concatenate',
#     'config': {'name': 'branch_t1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['t1_pre', 0, 0, {}], ['t1_low', 0, 0, {}]]]},
#    {'name': 'branch_t2',
#     'class_name': 'Concatenate',
#     'config': {'name': 'branch_t2',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['t1_pre', 0, 0, {}], ['t2', 0, 0, {}]]]},
#    {'name': 'branch_fl',
#     'class_name': 'Concatenate',
#     'config': {'name': 'branch_fl',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['t1_pre', 0, 0, {}], ['fl', 0, 0, {}]]]},
#    {'name': 'branch_uad',
#     'class_name': 'Concatenate',
#     'config': {'name': 'branch_uad',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['t1_pre', 0, 0, {}], ['uad', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_1_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['branch_t1', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_1_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['branch_t2', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_1_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['branch_fl', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_1_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['branch_uad', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_1_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_1_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_1_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_1_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_1_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_1_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_1_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_1_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_1_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_1_0', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_1_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_1_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_1_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_1_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_1_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_1_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_1_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_1_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_1_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_1_1', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_1_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_1_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_1_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_1_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_1_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'b1_maxpool_1',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b1_maxpool_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b1_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'b2_maxpool_1',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b2_maxpool_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b2_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'b3_maxpool_1',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b3_maxpool_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b3_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'b4_maxpool_1',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b4_maxpool_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b4_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_2_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b1_maxpool_1', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_2_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b2_maxpool_1', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_2_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b3_maxpool_1', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_2_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b4_maxpool_1', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_2_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_2_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_2_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_2_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_2_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_2_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_2_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_2_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_2_0', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_2_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_2_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_2_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_2_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_2_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_2_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_2_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_2_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_2_1', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_2_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_2_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_2_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_2_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'b1_maxpool_2',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b1_maxpool_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b1_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'b2_maxpool_2',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b2_maxpool_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b2_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'b3_maxpool_2',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b3_maxpool_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b3_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'b4_maxpool_2',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b4_maxpool_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b4_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_3_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b1_maxpool_2', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_3_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b2_maxpool_2', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_3_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b3_maxpool_2', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_3_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b4_maxpool_2', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_3_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_3_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_3_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_3_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_3_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_3_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_3_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_3_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'b1_conv_enc_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b1_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'b2_conv_enc_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b2_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'b3_conv_enc_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b3_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b3_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'b4_conv_enc_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b4_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_b4_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'relu_b1_conv_enc_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b1_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b1_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'relu_b2_conv_enc_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b2_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b2_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'relu_b3_conv_enc_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b3_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b3_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'relu_b4_conv_enc_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_b4_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['b4_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'b1_maxpool_3',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b1_maxpool_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b1_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'b2_maxpool_3',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b2_maxpool_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b2_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'b3_maxpool_3',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b3_maxpool_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b3_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'b4_maxpool_3',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'b4_maxpool_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_b4_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'b1_conv_center',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b1_conv_center',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['b1_maxpool_3', 0, 0, {}]]]},
#    {'name': 'b2_conv_center',
#     'class_name': 'Conv2D',
#     'config': {'name': 'b2_conv_center',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
# ...
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_enc_3_0', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_enc_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_enc_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'fbst_conv_enc_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_enc_3_1', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_enc_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_enc_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'fbst_maxpool_3',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'fbst_maxpool_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': (2, 2),
#      'padding': 'valid',
#      'strides': (2, 2),
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['relu_fbst_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'fbst_conv_center',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_center',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['fbst_maxpool_3', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_center',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_center',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_center', 0, 0, {}]]]},
#    {'name': 'fbst_add_center',
#     'class_name': 'Add',
#     'config': {'name': 'fbst_add_center',
#      'trainable': True,
#      'dtype': 'float32'},
#     'inbound_nodes': [[['fbst_maxpool_3', 0, 0, {}],
#       ['relu_fbst_conv_center', 0, 0, {}]]]},
#    {'name': 'fbst_upsample_2',
#     'class_name': 'UpSampling2D',
#     'config': {'name': 'fbst_upsample_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'size': (2, 2),
#      'data_format': 'channels_last',
#      'interpolation': 'nearest'},
#     'inbound_nodes': [[['fbst_add_center', 0, 0, {}]]]},
#    {'name': 'fbst_cat_1',
#     'class_name': 'Concatenate',
#     'config': {'name': 'fbst_cat_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['fbst_upsample_2', 0, 0, {}],
#       ['relu_fbst_conv_enc_3_2', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_2_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['fbst_cat_1', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_2_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_2_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_2_0', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_2_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_2_0', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_2_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_2_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_2_1', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_2_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_2_1', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_2_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_2_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_2_2', 0, 0, {}]]]},
#    {'name': 'fbst_upsample_3',
#     'class_name': 'UpSampling2D',
#     'config': {'name': 'fbst_upsample_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'size': (2, 2),
#      'data_format': 'channels_last',
#      'interpolation': 'nearest'},
#     'inbound_nodes': [[['relu_fbst_conv_dec_2_2', 0, 0, {}]]]},
#    {'name': 'fbst_cat_2',
#     'class_name': 'Concatenate',
#     'config': {'name': 'fbst_cat_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['fbst_upsample_3', 0, 0, {}],
#       ['relu_fbst_conv_enc_2_2', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_3_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['fbst_cat_2', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_3_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_3_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_3_0', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_3_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_3_0', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_3_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_3_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_3_1', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_3_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_3_1', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_3_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_3_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_3_2', 0, 0, {}]]]},
#    {'name': 'fbst_upsample_4',
#     'class_name': 'UpSampling2D',
#     'config': {'name': 'fbst_upsample_4',
#      'trainable': True,
#      'dtype': 'float32',
#      'size': (2, 2),
#      'data_format': 'channels_last',
#      'interpolation': 'nearest'},
#     'inbound_nodes': [[['relu_fbst_conv_dec_3_2', 0, 0, {}]]]},
#    {'name': 'fbst_cat_3',
#     'class_name': 'Concatenate',
#     'config': {'name': 'fbst_cat_3',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': -1},
#     'inbound_nodes': [[['fbst_upsample_4', 0, 0, {}],
#       ['relu_fbst_conv_enc_1_2', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_4_0',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_4_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['fbst_cat_3', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_4_0',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_4_0',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_4_0', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_4_1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_4_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_4_0', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_4_1',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_4_1',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_4_1', 0, 0, {}]]]},
#    {'name': 'fbst_conv_dec_4_2',
#     'class_name': 'Conv2D',
#     'config': {'name': 'fbst_conv_dec_4_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 32,
#      'kernel_size': (3, 3),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_4_1', 0, 0, {}]]]},
#    {'name': 'relu_fbst_conv_dec_4_2',
#     'class_name': 'Activation',
#     'config': {'name': 'relu_fbst_conv_dec_4_2',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['fbst_conv_dec_4_2', 0, 0, {}]]]},
#    {'name': 'model_output',
#     'class_name': 'Conv2D',
#     'config': {'name': 'model_output',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 1,
#      'kernel_size': (1, 1),
#      'strides': (1, 1),
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': (1, 1),
#      'activation': 'linear',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['relu_fbst_conv_dec_4_2', 0, 0, {}]]]},
#    {'name': 'linear_model_output',
#     'class_name': 'Activation',
#     'config': {'name': 'linear_model_output',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'linear'},
#     'inbound_nodes': [[['model_output', 0, 0, {}]]]}],
#   'input_layers': [['model_input', 0, 0]],
#   'output_layers': [['linear_model_output', 0, 0]]},
#  'keras_version': '2.3.1',
#  'backend': 'tensorflow'}

# %%
model_br.model.to_json()
# Out:
# '{"class_name": "Model", "config": {"name": "model_1", "layers": [{"name": "model_input", "class_name": "InputLayer", "config": {"batch_input_shape": [null, 240, 240, 35], "dtype": "float32", "sparse": false, "name": "model_input"}, "inbound_nodes": []}, {"name": "t1_pre", "class_name": "Lambda", "config": {"name": "t1_pre", "trainable": true, "dtype": "float32", "function": ["4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\\nAABzAAAAAA==\\n", null, [4, 5]], "function_type": "lambda", "output_shape": null, "output_shape_type": "raw", "arguments": {}}, "inbound_nodes": [[["model_input", 0, 0, {}]]]}, {"name": "t1_low", "class_name": "Lambda", "config": {"name": "t1_low", "trainable": true, "dtype": "float32", "function": ["4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\\nAABzAAAAAA==\\n", null, [4, 5]], "function_type": "lambda", "output_shape": null, "output_shape_type": "raw", "arguments": {}}, "inbound_nodes": [[["model_input", 0, 0, {}]]]}, {"name": "t2", "class_name": "Lambda", "config": {"name": "t2", "trainable": true, "dtype": "float32", "function": ["4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\\nAABzAAAAAA==\\n", null, [4, 5]], "function_type": "lambda", "output_shape": null, "output_shape_type": "raw", "arguments": {}}, "inbound_nodes": [[["model_input", 0, 0, {}]]]}, {"name": "fl", "class_name": "Lambda", "config": {"name": "fl", "trainable": true, "dtype": "float32", "function": ["4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\\nAABzAAAAAA==\\n", null, [4, 5]], "function_type": "lambda", "output_shape": null, "output_shape_type": "raw", "arguments": {}}, "inbound_nodes": [[["model_input", 0, 0, {}]]]}, {"name": "uad", "class_name": "Lambda", "config": {"name": "uad", "trainable": true, "dtype": "float32", "function": ["4wEAAAAAAAAAAQAAAAUAAAATAAAAcxIAAAB8AGQBiABkAIgBhQNmAhkAUwApAk4uqQApAdoCaXAp\\nAtoDaWR42ghudW1fbW9kc3IBAAAA+k8vaG9tZS9zcml2YXRoc2EvcHJvamVjdHMvU3VidGxlR2Fk\\nL3RyYWluL3N1YnRsZS9kbm4vZ2VuZXJhdG9ycy9icmFuY2hfdW5ldDJkLnB52gg8bGFtYmRhPqwA\\nAABzAAAAAA==\\n", null, [4, 5]], "function_type": "lambda", "output_shape": null, "output_shape_type": "raw", "arguments": {}}, "inbound_nodes": [[["model_input", 0, 0, {}]]]}, {"name": "branch_t1", "class_name": "Concatenate", "config": {"name": "branch_t1", "trainable": true, "dtype": "float32", "axis": -1}, "inbound_nodes": [[["t1_pre", 0, 0, {}], ["t1_low", 0, 0, {}]]]}, {"name": "branch_t2", "class_name": "Concatenate", "config": {"name": "branch_t2", "trainable": true, "dtype": "float32", "axis": -1}, "inbound_nodes": [[["t1_pre", 0, 0, {}], ["t2", 0, 0, {}]]]}, {"name": "branch_fl", "class_name": "Concatenate", "config": {"name": "branch_fl", "trainable": true, "dtype": "float32", "axis": -1}, "inbound_nodes": [[["t1_pre", 0, 0, {}], ["fl", 0, 0, {}]]]}, {"name": "branch_uad", "class_name": "Concatenate", "config": {"name": "branch_uad", "trainable": true, "dtype": "float32", "axis": -1}, "inbound_nodes": [[["t1_pre", 0, 0, {}], ["uad", 0, 0, {}]]]}, {"name": "b1_conv_enc_1_0", "class_name": "Conv2D", "config": {"name": "b1_conv_enc_1_0", "trainable": true, "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": " ...

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import os
import json

from subtle.dnn.generators import GeneratorRRDB2D, GeneratorRRDB3D
import subtle.utils.io as suio
from subtle.data_loaders.slice_loader import SliceLoader
import subtle.subtle_loss as suloss
from subtle.dnn.helpers import clear_keras_memory, set_keras_memory
from keras.optimizers import Adam

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

plt.rcParams['figure.figsize'] = (10, 8)
plt.set_cmap('gray')
# Out:
# /home/srivathsa/projects/SubtleGad/train/subtle/utils/hyperparameter.py:8: UserWarning: Module test_tube not found - hyperparameter related functions cannot be used
#   warnings.warn('Module test_tube not found - hyperparameter related functions cannot be used')
# WARNING:tensorflow:From /home/srivathsa/projects/SubtleGad/train/subtle/subtle_loss.py:19: The name tf.log is deprecated. Please use tf.math.log instead.
# Using TensorFlow backend.

# %%
clear_keras_memory()
set_keras_memory(1.0)

loss_function = suloss.mixed_loss(l1_lambda=1.0, ssim_lambda=0.0)
metrics_monitor = [suloss.l1_loss]

model_main = GeneratorRRDB2D(
                num_channel_input=7, num_channel_output=1,
                img_rows=256, img_cols=256,
                loss_function=loss_function,
                metrics_monitor=metrics_monitor,
                lr_init=0.001,
                verbose=1,
                compile_model=True,
                model_config='base'
            )
# Out:
# Building RRDB 2D model...
# config vals 6 15 32
# Tensor("model_input:0", shape=(?, 256, 256, 7), dtype=float32)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        (None, 256, 256, 7)  0
# __________________________________________________________________________________________________
# conv_pass1 (Conv2D)             (None, 256, 256, 64) 4096        model_input[0][0]
# __________________________________________________________________________________________________
# conv_pass2 (Conv2D)             (None, 256, 256, 64) 36928       conv_pass1[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_0 (Conv2D)            (None, 256, 256, 32) 18464       conv_pass2[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_1 (Concatenate)        (None, 256, 256, 96) 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb0_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_2 (Concatenate)        (None, 256, 256, 128 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
#                                                                  conv_rdb0_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb0_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_3 (Concatenate)        (None, 256, 256, 160 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
#                                                                  conv_rdb0_1[0][0]
#                                                                  conv_rdb0_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb0_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_4 (Concatenate)        (None, 256, 256, 192 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
#                                                                  conv_rdb0_1[0][0]
#                                                                  conv_rdb0_2[0][0]
#                                                                  conv_rdb0_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb0_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_5 (Concatenate)        (None, 256, 256, 224 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
#                                                                  conv_rdb0_1[0][0]
#                                                                  conv_rdb0_2[0][0]
#                                                                  conv_rdb0_3[0][0]
#                                                                  conv_rdb0_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb0_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb0_6 (Concatenate)        (None, 256, 256, 256 0           conv_pass2[0][0]
#                                                                  conv_rdb0_0[0][0]
#                                                                  conv_rdb0_1[0][0]
#                                                                  conv_rdb0_2[0][0]
#                                                                  conv_rdb0_3[0][0]
#                                                                  conv_rdb0_4[0][0]
#                                                                  conv_rdb0_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb0_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb0_6[0][0]
# __________________________________________________________________________________________________
# add_rdb0 (Add)                  (None, 256, 256, 64) 0           conv_rdb0_local[0][0]
#                                                                  conv_pass2[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb0[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb1_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
#                                                                  conv_rdb1_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb1_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
#                                                                  conv_rdb1_1[0][0]
#                                                                  conv_rdb1_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb1_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
#                                                                  conv_rdb1_1[0][0]
#                                                                  conv_rdb1_2[0][0]
#                                                                  conv_rdb1_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb1_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
#                                                                  conv_rdb1_1[0][0]
#                                                                  conv_rdb1_2[0][0]
#                                                                  conv_rdb1_3[0][0]
#                                                                  conv_rdb1_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb1_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb1_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb0[0][0]
#                                                                  conv_rdb1_0[0][0]
#                                                                  conv_rdb1_1[0][0]
#                                                                  conv_rdb1_2[0][0]
#                                                                  conv_rdb1_3[0][0]
#                                                                  conv_rdb1_4[0][0]
#                                                                  conv_rdb1_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb1_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb1_6[0][0]
# __________________________________________________________________________________________________
# add_rdb1 (Add)                  (None, 256, 256, 64) 0           conv_rdb1_local[0][0]
#                                                                  add_rdb0[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb1[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb2_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
#                                                                  conv_rdb2_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb2_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
#                                                                  conv_rdb2_1[0][0]
#                                                                  conv_rdb2_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb2_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
#                                                                  conv_rdb2_1[0][0]
#                                                                  conv_rdb2_2[0][0]
#                                                                  conv_rdb2_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb2_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
#                                                                  conv_rdb2_1[0][0]
#                                                                  conv_rdb2_2[0][0]
#                                                                  conv_rdb2_3[0][0]
#                                                                  conv_rdb2_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb2_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb2_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb1[0][0]
#                                                                  conv_rdb2_0[0][0]
#                                                                  conv_rdb2_1[0][0]
#                                                                  conv_rdb2_2[0][0]
#                                                                  conv_rdb2_3[0][0]
#                                                                  conv_rdb2_4[0][0]
#                                                                  conv_rdb2_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb2_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb2_6[0][0]
# __________________________________________________________________________________________________
# add_rdb2 (Add)                  (None, 256, 256, 64) 0           conv_rdb2_local[0][0]
#                                                                  add_rdb1[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb2[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb3_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
#                                                                  conv_rdb3_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb3_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
#                                                                  conv_rdb3_1[0][0]
#                                                                  conv_rdb3_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb3_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
#                                                                  conv_rdb3_1[0][0]
#                                                                  conv_rdb3_2[0][0]
#                                                                  conv_rdb3_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb3_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
#                                                                  conv_rdb3_1[0][0]
#                                                                  conv_rdb3_2[0][0]
#                                                                  conv_rdb3_3[0][0]
#                                                                  conv_rdb3_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb3_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb3_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb2[0][0]
#                                                                  conv_rdb3_0[0][0]
#                                                                  conv_rdb3_1[0][0]
#                                                                  conv_rdb3_2[0][0]
#                                                                  conv_rdb3_3[0][0]
#                                                                  conv_rdb3_4[0][0]
#                                                                  conv_rdb3_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb3_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb3_6[0][0]
# __________________________________________________________________________________________________
# add_rdb3 (Add)                  (None, 256, 256, 64) 0           conv_rdb3_local[0][0]
#                                                                  add_rdb2[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb3[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb4_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
#                                                                  conv_rdb4_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb4_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
#                                                                  conv_rdb4_1[0][0]
#                                                                  conv_rdb4_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb4_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
#                                                                  conv_rdb4_1[0][0]
#                                                                  conv_rdb4_2[0][0]
#                                                                  conv_rdb4_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb4_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
#                                                                  conv_rdb4_1[0][0]
#                                                                  conv_rdb4_2[0][0]
#                                                                  conv_rdb4_3[0][0]
#                                                                  conv_rdb4_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb4_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb4_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb3[0][0]
#                                                                  conv_rdb4_0[0][0]
#                                                                  conv_rdb4_1[0][0]
#                                                                  conv_rdb4_2[0][0]
#                                                                  conv_rdb4_3[0][0]
#                                                                  conv_rdb4_4[0][0]
#                                                                  conv_rdb4_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb4_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb4_6[0][0]
# __________________________________________________________________________________________________
# add_rdb4 (Add)                  (None, 256, 256, 64) 0           conv_rdb4_local[0][0]
#                                                                  add_rdb3[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb4[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb5_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
#                                                                  conv_rdb5_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb5_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
#                                                                  conv_rdb5_1[0][0]
#                                                                  conv_rdb5_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb5_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
#                                                                  conv_rdb5_1[0][0]
#                                                                  conv_rdb5_2[0][0]
#                                                                  conv_rdb5_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb5_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
#                                                                  conv_rdb5_1[0][0]
#                                                                  conv_rdb5_2[0][0]
#                                                                  conv_rdb5_3[0][0]
#                                                                  conv_rdb5_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb5_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb5_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb4[0][0]
#                                                                  conv_rdb5_0[0][0]
#                                                                  conv_rdb5_1[0][0]
#                                                                  conv_rdb5_2[0][0]
#                                                                  conv_rdb5_3[0][0]
#                                                                  conv_rdb5_4[0][0]
#                                                                  conv_rdb5_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb5_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb5_6[0][0]
# __________________________________________________________________________________________________
# add_rdb5 (Add)                  (None, 256, 256, 64) 0           conv_rdb5_local[0][0]
#                                                                  add_rdb4[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb5[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb6_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
#                                                                  conv_rdb6_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb6_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
#                                                                  conv_rdb6_1[0][0]
#                                                                  conv_rdb6_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb6_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
#                                                                  conv_rdb6_1[0][0]
#                                                                  conv_rdb6_2[0][0]
#                                                                  conv_rdb6_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb6_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
#                                                                  conv_rdb6_1[0][0]
#                                                                  conv_rdb6_2[0][0]
#                                                                  conv_rdb6_3[0][0]
#                                                                  conv_rdb6_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb6_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb6_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb5[0][0]
#                                                                  conv_rdb6_0[0][0]
#                                                                  conv_rdb6_1[0][0]
#                                                                  conv_rdb6_2[0][0]
#                                                                  conv_rdb6_3[0][0]
#                                                                  conv_rdb6_4[0][0]
#                                                                  conv_rdb6_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb6_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb6_6[0][0]
# __________________________________________________________________________________________________
# add_rdb6 (Add)                  (None, 256, 256, 64) 0           conv_rdb6_local[0][0]
#                                                                  add_rdb5[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb6[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb7_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
#                                                                  conv_rdb7_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb7_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
#                                                                  conv_rdb7_1[0][0]
#                                                                  conv_rdb7_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb7_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
#                                                                  conv_rdb7_1[0][0]
#                                                                  conv_rdb7_2[0][0]
#                                                                  conv_rdb7_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb7_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
#                                                                  conv_rdb7_1[0][0]
#                                                                  conv_rdb7_2[0][0]
#                                                                  conv_rdb7_3[0][0]
#                                                                  conv_rdb7_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb7_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb7_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb6[0][0]
#                                                                  conv_rdb7_0[0][0]
#                                                                  conv_rdb7_1[0][0]
#                                                                  conv_rdb7_2[0][0]
#                                                                  conv_rdb7_3[0][0]
#                                                                  conv_rdb7_4[0][0]
#                                                                  conv_rdb7_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb7_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb7_6[0][0]
# __________________________________________________________________________________________________
# add_rdb7 (Add)                  (None, 256, 256, 64) 0           conv_rdb7_local[0][0]
#                                                                  add_rdb6[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb7[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb8_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
#                                                                  conv_rdb8_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb8_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
#                                                                  conv_rdb8_1[0][0]
#                                                                  conv_rdb8_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb8_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
#                                                                  conv_rdb8_1[0][0]
#                                                                  conv_rdb8_2[0][0]
#                                                                  conv_rdb8_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_4 (Conv2D)            (None, 256, 256, 32) 55328       cat_rdb8_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_5 (Concatenate)        (None, 256, 256, 224 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
#                                                                  conv_rdb8_1[0][0]
#                                                                  conv_rdb8_2[0][0]
#                                                                  conv_rdb8_3[0][0]
#                                                                  conv_rdb8_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_5 (Conv2D)            (None, 256, 256, 32) 64544       cat_rdb8_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb8_6 (Concatenate)        (None, 256, 256, 256 0           add_rdb7[0][0]
#                                                                  conv_rdb8_0[0][0]
#                                                                  conv_rdb8_1[0][0]
#                                                                  conv_rdb8_2[0][0]
#                                                                  conv_rdb8_3[0][0]
#                                                                  conv_rdb8_4[0][0]
#                                                                  conv_rdb8_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb8_local (Conv2D)        (None, 256, 256, 64) 16448       cat_rdb8_6[0][0]
# __________________________________________________________________________________________________
# add_rdb8 (Add)                  (None, 256, 256, 64) 0           conv_rdb8_local[0][0]
#                                                                  add_rdb7[0][0]
# __________________________________________________________________________________________________
# conv_rdb9_0 (Conv2D)            (None, 256, 256, 32) 18464       add_rdb8[0][0]
# __________________________________________________________________________________________________
# cat_rdb9_1 (Concatenate)        (None, 256, 256, 96) 0           add_rdb8[0][0]
#                                                                  conv_rdb9_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb9_1 (Conv2D)            (None, 256, 256, 32) 27680       cat_rdb9_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb9_2 (Concatenate)        (None, 256, 256, 128 0           add_rdb8[0][0]
#                                                                  conv_rdb9_0[0][0]
#                                                                  conv_rdb9_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb9_2 (Conv2D)            (None, 256, 256, 32) 36896       cat_rdb9_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb9_3 (Concatenate)        (None, 256, 256, 160 0           add_rdb8[0][0]
#                                                                  conv_rdb9_0[0][0]
#                                                                  conv_rdb9_1[0][0]
#                                                                  conv_rdb9_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb9_3 (Conv2D)            (None, 256, 256, 32) 46112       cat_rdb9_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb9_4 (Concatenate)        (None, 256, 256, 192 0           add_rdb8[0][0]
#                                                                  conv_rdb9_0[0][0]
#                                                                  conv_rdb9_1[0][0]
#                                                                  conv_rdb9_2[0][0]
# ...
#                                                                  conv_rdb12_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb12_3 (Conv2D)           (None, 256, 256, 32) 46112       cat_rdb12_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb12_4 (Concatenate)       (None, 256, 256, 192 0           add_rdb11[0][0]
#                                                                  conv_rdb12_0[0][0]
#                                                                  conv_rdb12_1[0][0]
#                                                                  conv_rdb12_2[0][0]
#                                                                  conv_rdb12_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb12_4 (Conv2D)           (None, 256, 256, 32) 55328       cat_rdb12_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb12_5 (Concatenate)       (None, 256, 256, 224 0           add_rdb11[0][0]
#                                                                  conv_rdb12_0[0][0]
#                                                                  conv_rdb12_1[0][0]
#                                                                  conv_rdb12_2[0][0]
#                                                                  conv_rdb12_3[0][0]
#                                                                  conv_rdb12_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb12_5 (Conv2D)           (None, 256, 256, 32) 64544       cat_rdb12_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb12_6 (Concatenate)       (None, 256, 256, 256 0           add_rdb11[0][0]
#                                                                  conv_rdb12_0[0][0]
#                                                                  conv_rdb12_1[0][0]
#                                                                  conv_rdb12_2[0][0]
#                                                                  conv_rdb12_3[0][0]
#                                                                  conv_rdb12_4[0][0]
#                                                                  conv_rdb12_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb12_local (Conv2D)       (None, 256, 256, 64) 16448       cat_rdb12_6[0][0]
# __________________________________________________________________________________________________
# add_rdb12 (Add)                 (None, 256, 256, 64) 0           conv_rdb12_local[0][0]
#                                                                  add_rdb11[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_0 (Conv2D)           (None, 256, 256, 32) 18464       add_rdb12[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_1 (Concatenate)       (None, 256, 256, 96) 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_1 (Conv2D)           (None, 256, 256, 32) 27680       cat_rdb13_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_2 (Concatenate)       (None, 256, 256, 128 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
#                                                                  conv_rdb13_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_2 (Conv2D)           (None, 256, 256, 32) 36896       cat_rdb13_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_3 (Concatenate)       (None, 256, 256, 160 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
#                                                                  conv_rdb13_1[0][0]
#                                                                  conv_rdb13_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_3 (Conv2D)           (None, 256, 256, 32) 46112       cat_rdb13_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_4 (Concatenate)       (None, 256, 256, 192 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
#                                                                  conv_rdb13_1[0][0]
#                                                                  conv_rdb13_2[0][0]
#                                                                  conv_rdb13_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_4 (Conv2D)           (None, 256, 256, 32) 55328       cat_rdb13_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_5 (Concatenate)       (None, 256, 256, 224 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
#                                                                  conv_rdb13_1[0][0]
#                                                                  conv_rdb13_2[0][0]
#                                                                  conv_rdb13_3[0][0]
#                                                                  conv_rdb13_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_5 (Conv2D)           (None, 256, 256, 32) 64544       cat_rdb13_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb13_6 (Concatenate)       (None, 256, 256, 256 0           add_rdb12[0][0]
#                                                                  conv_rdb13_0[0][0]
#                                                                  conv_rdb13_1[0][0]
#                                                                  conv_rdb13_2[0][0]
#                                                                  conv_rdb13_3[0][0]
#                                                                  conv_rdb13_4[0][0]
#                                                                  conv_rdb13_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb13_local (Conv2D)       (None, 256, 256, 64) 16448       cat_rdb13_6[0][0]
# __________________________________________________________________________________________________
# add_rdb13 (Add)                 (None, 256, 256, 64) 0           conv_rdb13_local[0][0]
#                                                                  add_rdb12[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_0 (Conv2D)           (None, 256, 256, 32) 18464       add_rdb13[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_1 (Concatenate)       (None, 256, 256, 96) 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_1 (Conv2D)           (None, 256, 256, 32) 27680       cat_rdb14_1[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_2 (Concatenate)       (None, 256, 256, 128 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
#                                                                  conv_rdb14_1[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_2 (Conv2D)           (None, 256, 256, 32) 36896       cat_rdb14_2[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_3 (Concatenate)       (None, 256, 256, 160 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
#                                                                  conv_rdb14_1[0][0]
#                                                                  conv_rdb14_2[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_3 (Conv2D)           (None, 256, 256, 32) 46112       cat_rdb14_3[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_4 (Concatenate)       (None, 256, 256, 192 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
#                                                                  conv_rdb14_1[0][0]
#                                                                  conv_rdb14_2[0][0]
#                                                                  conv_rdb14_3[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_4 (Conv2D)           (None, 256, 256, 32) 55328       cat_rdb14_4[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_5 (Concatenate)       (None, 256, 256, 224 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
#                                                                  conv_rdb14_1[0][0]
#                                                                  conv_rdb14_2[0][0]
#                                                                  conv_rdb14_3[0][0]
#                                                                  conv_rdb14_4[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_5 (Conv2D)           (None, 256, 256, 32) 64544       cat_rdb14_5[0][0]
# __________________________________________________________________________________________________
# cat_rdb14_6 (Concatenate)       (None, 256, 256, 256 0           add_rdb13[0][0]
#                                                                  conv_rdb14_0[0][0]
#                                                                  conv_rdb14_1[0][0]
#                                                                  conv_rdb14_2[0][0]
#                                                                  conv_rdb14_3[0][0]
#                                                                  conv_rdb14_4[0][0]
#                                                                  conv_rdb14_5[0][0]
# __________________________________________________________________________________________________
# conv_rdb14_local (Conv2D)       (None, 256, 256, 64) 16448       cat_rdb14_6[0][0]
# __________________________________________________________________________________________________
# add_rdb14 (Add)                 (None, 256, 256, 64) 0           conv_rdb14_local[0][0]
#                                                                  add_rdb13[0][0]
# __________________________________________________________________________________________________
# cat_rdb_list (Concatenate)      (None, 256, 256, 960 0           add_rdb0[0][0]
#                                                                  add_rdb1[0][0]
#                                                                  add_rdb2[0][0]
#                                                                  add_rdb3[0][0]
#                                                                  add_rdb4[0][0]
#                                                                  add_rdb5[0][0]
#                                                                  add_rdb6[0][0]
#                                                                  add_rdb7[0][0]
#                                                                  add_rdb8[0][0]
#                                                                  add_rdb9[0][0]
#                                                                  add_rdb10[0][0]
#                                                                  add_rdb11[0][0]
#                                                                  add_rdb12[0][0]
#                                                                  add_rdb13[0][0]
#                                                                  add_rdb14[0][0]
# __________________________________________________________________________________________________
# conv_post_rdb_1 (Conv2D)        (None, 256, 256, 64) 61504       cat_rdb_list[0][0]
# __________________________________________________________________________________________________
# conv_post_rdb_2 (Conv2D)        (None, 256, 256, 64) 36928       conv_post_rdb_1[0][0]
# __________________________________________________________________________________________________
# final_add (Add)                 (None, 256, 256, 64) 0           conv_post_rdb_2[0][0]
#                                                                  conv_pass1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 1)  577         final_add[0][0]
# ==================================================================================================
# Total params: 4,122,113
# Trainable params: 4,122,113
# Non-trainable params: 0
# __________________________________________________________________________________________________
# <keras.engine.training.Model object at 0x7ff600741dd8>

# %%
clear_keras_memory()
set_keras_memory(1.0)

loss_function = suloss.mixed_loss(l1_lambda=1.0, ssim_lambda=0.0)
metrics_monitor = [suloss.l1_loss]

model_main = GeneratorRRDB3D(
                num_channel_input=7, num_channel_output=1,
                img_rows=256, img_cols=256, img_depth=128,
                loss_function=loss_function,
                metrics_monitor=metrics_monitor,
                lr_init=0.001,
                verbose=1,
                compile_model=True,
                model_config='base'
            )

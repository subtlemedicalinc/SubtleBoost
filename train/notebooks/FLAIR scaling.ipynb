# %%
import subtle.utils.io as suio
import numpy as np
import os
import shutil
from glob import glob
import matplotlib.pyplot as plt
plt.set_cmap('gray')
plt.rcParams['figure.figsize'] = (12, 10)

# %%
img_path = '/home/srivathsa/projects/studies/gad/tiantan/preprocess/data_fl/NO44.h5'
data = suio.load_file(img_path, params={'h5_key': 'all'})
sl = 91
disp = np.hstack(data[0, sl, [2, 3]])

# %%
plt.imshow(disp)

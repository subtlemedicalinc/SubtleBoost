# %%
import matplotlib.pyplot as plt
plt.set_cmap('gray')
plt.rcParams['figure.figsize'] = (10, 8)

import numpy as np

# %%
d1 = np.load('/mnt/raid/jiang/projects/SubtleGAN/data/MRNet-v1.0/train/axial/0000.npy')
d2 = np.load('/mnt/raid/jiang/projects/SubtleGAN/data/MRNet-v1.0/train/coronal/0000.npy')
d3 = np.load('/mnt/raid/jiang/projects/SubtleGAN/data/MRNet-v1.0/train/sagittal/0000.npy')
print(d1.shape, d2.shape, d3.shape)
# Out:
# (44, 256, 256) (36, 256, 256) (36, 256, 256)

# %%
plt.imshow(d1[22])

# %%
plt.imshow(d2[18])

# %%
plt.imshow(d1[:, :, 128])

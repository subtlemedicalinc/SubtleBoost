# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread("model/MMGAN/mmgan_brats_zeros_single_0101/vis/1101/BraTS2021_00709/15_output.png")
img2 = cv2.imread("model/MMGAN/mmgan_brats_zeros_single_0101/vis_mmt_format_new_2/023/BraTS2021_00709/065_output.png")

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
